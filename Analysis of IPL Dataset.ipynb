# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read the file
ipl = pd.read_csv('matches.csv')
ipl
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
#Fetch 1st 3 records
ipl.head(3)
# Out:
#    id    Season       city        date                team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017       Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
#Another approach to fetch 1st 3 records
ipl[:3]
# Out:
#    id    Season       city        date                team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017       Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
#fetch last 3 records
ipl.tail(3)
# Out:
#         id    Season           city        date                team1  \
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019  Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019       Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019       Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 753           0       Delhi Capitals            0               2
# 754           0  Chennai Super Kings            0               6
# 755           0       Mumbai Indians            1               0
#
#     player_of_match                               venue        umpire1  \
# 753         RR Pant                    ACA-VDCA Stadium            NaN
# ...

# %%
#How many rows and columns present?
ipl.shape
# Out:
# (756, 18)

# %%
#List out the names of columns
ipl.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
#check the abstract summary of data
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
# id                 756 non-null int64
# Season             756 non-null object
# city               749 non-null object
# date               756 non-null object
# team1              756 non-null object
# team2              756 non-null object
# toss_winner        756 non-null object
# toss_decision      756 non-null object
# result             756 non-null object
# dl_applied         756 non-null int64
# winner             752 non-null object
# win_by_runs        756 non-null int64
# win_by_wickets     756 non-null int64
# player_of_match    752 non-null object
# venue              756 non-null object
# umpire1            754 non-null object
# umpire2            754 non-null object
# umpire3            119 non-null object
# dtypes: int64(4), object(14)
# memory usage: 106.4+ KB

# %%
#check the missing values
ipl.isna().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
#check descriptive statistics
ipl.describe()
# Out:
#                  id  dl_applied  win_by_runs  win_by_wickets
# count    756.000000  756.000000   756.000000      756.000000
# mean    1792.178571    0.025132    13.283069        3.350529
# std     3464.478148    0.156630    23.471144        3.387963
# min        1.000000    0.000000     0.000000        0.000000
# 25%      189.750000    0.000000     0.000000        0.000000
# 50%      378.500000    0.000000     0.000000        4.000000
# 75%      567.250000    0.000000    19.000000        6.000000
# max    11415.000000    1.000000   146.000000       10.000000

# %%
#check the data of any column
ipl.team1
# Out:
# 0              Sunrisers Hyderabad
# 1                   Mumbai Indians
# 2                    Gujarat Lions
# 3           Rising Pune Supergiant
# 4      Royal Challengers Bangalore
#                   ...
# 751          Kolkata Knight Riders
# 752            Chennai Super Kings
# 753            Sunrisers Hyderabad
# 754                 Delhi Capitals
# 755                 Mumbai Indians
# Name: team1, Length: 756, dtype: object

# %%
#To get the any columns use following
ipl[['team1','team2']]
# Out:
#                            team1                        team2
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 751        Kolkata Knight Riders               Mumbai Indians
# 752          Chennai Super Kings               Mumbai Indians
# 753          Sunrisers Hyderabad               Delhi Capitals
# 754               Delhi Capitals          Chennai Super Kings
# 755               Mumbai Indians          Chennai Super Kings
#
# [756 rows x 2 columns]

# %%
ipl.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
#Fetch City and result column
ipl[['city','result']]
# Out:
#               city  result
# 0        Hyderabad  normal
# 1             Pune  normal
# 2           Rajkot  normal
# 3           Indore  normal
# 4        Bangalore  normal
# ..             ...     ...
# 751         Mumbai  normal
# 752        Chennai  normal
# 753  Visakhapatnam  normal
# 754  Visakhapatnam  normal
# 755      Hyderabad  normal
#
# [756 rows x 2 columns]

# %% [markdown]
# # Fetch the data of Season 2017

# %%
ipl.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ipl.groupby('Season').get_group('IPL-2017').head(3)
# Out:
#    id    Season       city        date                team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017       Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %% [markdown]
# # How many matches played in season 2018

# %%
ipl.groupby('Season').get_group('IPL-2018').shape
# Out:
# (60, 18)

# %%
print(len(ipl.groupby('Season').get_group('IPL-2018')), 'no. of matches have been played in 2018 season')
# Out:
# 60 no. of matches have been played in 2018 season

# %% [markdown]
# # How many matches played at Rajiv Gandhi International Stadium, Uppal

# %%
ipl.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
print(len(ipl[ipl.venue=='Rajiv Gandhi International Stadium, Uppal']), 'no of matches played at Rajiv Gandhi International Stadium, Uppal')
# Out:
# 56 no of matches played at Rajiv Gandhi International Stadium, Uppal

# %% [markdown]
# # Show the total seasons in dataset

# %%
sorted(ipl.Season.unique())
# Out:
# ['IPL-2008',
#  'IPL-2009',
#  'IPL-2010',
#  'IPL-2011',
#  'IPL-2012',
#  'IPL-2013',
#  'IPL-2014',
#  'IPL-2015',
#  'IPL-2016',
#  'IPL-2017',
#  'IPL-2018',
#  'IPL-2019']

# %% [markdown]
# # How many seasons data we have?

# %%
print(ipl.Season.nunique(),'Seasons data is present')
# Out:
# 12 Seasons data is present

# %% [markdown]
# # How many Number of matches played so far

# %%
len(ipl)
# Out:
# 756

# %% [markdown]
# # plot the count of matches played each season

# %%
ipl
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
ipl.groupby('Season')['id'].count().plot(kind = 'bar')
plt.title('Season vs no.of matches played',color = 'r')
plt.show()

# %%
ipl.groupby('Season')['id'].count().plot(kind = 'pie', autopct= '%.f%%', figsize = (10,5))
plt.show()

# %% [markdown]
# # Number of Matches played in each venue

# %%
list(ipl.groupby('venue')['Season'])
# Out:
# [('ACA-VDCA Stadium', 753    IPL-2019
#   754    IPL-2019
#   Name: Season, dtype: object), ('Barabati Stadium', 185    IPL-2010
#   188    IPL-2010
#   336    IPL-2012
#   347    IPL-2012
#   485    IPL-2014
#   490    IPL-2014
#   496    IPL-2014
#   Name: Season, dtype: object), ('Brabourne Stadium', 175    IPL-2010
#   187    IPL-2010
#   190    IPL-2010
#   193    IPL-2010
#   200    IPL-2010
#   206    IPL-2010
#   220    IPL-2010
#   514    IPL-2014
#   552    IPL-2015
#   557    IPL-2015
#   569    IPL-2015
#   Name: Season, dtype: object), ('Buffalo Park', 137    IPL-2009
#   143    IPL-2009
#   149    IPL-2009
#   Name: Season, dtype: object), ('De Beers Diamond Oval', 150    IPL-2009
#   151    IPL-2009
#   154    IPL-2009
#   Name: Season, dtype: object), ('Dr DY Patil Sports Academy', 71     IPL-2008
#   81     IPL-2008
#   85     IPL-2008
#   116    IPL-2008
#   174    IPL-2010
#   198    IPL-2010
#   230    IPL-2010
#   231    IPL-2010
#   232    IPL-2010
# ...

# %%
ipl['venue'].value_counts()
# Out:
# Eden Gardens                                            77
# M Chinnaswamy Stadium                                   73
# Wankhede Stadium                                        73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Subrata Roy Sahara Stadium                              17
# Dr DY Patil Sports Academy                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# SuperSport Park                                         12
# Sardar Patel Stadium, Motera                            12
# Brabourne Stadium                                       11
# ...

# %% [markdown]
# # Top 5 venues and most matches played

# %%
ipl['venue'].value_counts().head()
# Out:
# Eden Gardens                                 77
# M Chinnaswamy Stadium                        73
# Wankhede Stadium                             73
# Feroz Shah Kotla                             67
# Rajiv Gandhi International Stadium, Uppal    56
# Name: venue, dtype: int64

# %% [markdown]
# # Which Team won the most of tosses

# %%
ipl.head(3)
# Out:
#    id    Season       city        date                team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017       Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
ipl['toss_winner'].value_counts().head(1)
# Out:
# Mumbai Indians    98
# Name: toss_winner, dtype: int64

# %% [markdown]
# # who won the final match of season 2019?

# %%
ipl.groupby('Season').get_group('IPL-2019').tail(1).winner
# Out:
# 755    Mumbai Indians
# Name: winner, dtype: object

# %% [markdown]
# # Number of Matches played by each Team#

# %%
t1 = (ipl['team1'].value_counts())
t1
# Out:
# Mumbai Indians                 101
# Kings XI Punjab                 91
# Chennai Super Kings             89
# Royal Challengers Bangalore     85
# Kolkata Knight Riders           83
# Delhi Daredevils                72
# Rajasthan Royals                67
# Sunrisers Hyderabad             63
# Deccan Chargers                 43
# Pune Warriors                   20
# Gujarat Lions                   14
# Rising Pune Supergiant           8
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          7
# Delhi Capitals                   6
# Name: team1, dtype: int64

# %%
t2 = ipl['team2'].value_counts()
t2
# Out:
# Royal Challengers Bangalore    95
# Kolkata Knight Riders          95
# Delhi Daredevils               89
# Mumbai Indians                 86
# Kings XI Punjab                85
# Rajasthan Royals               80
# Chennai Super Kings            75
# Sunrisers Hyderabad            45
# Deccan Chargers                32
# Pune Warriors                  26
# Gujarat Lions                  16
# Delhi Capitals                 10
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: team2, dtype: int64

# %%
(t1+t2).sort_values(ascending = False)
# Out:
# Mumbai Indians                 187
# Royal Challengers Bangalore    180
# Kolkata Knight Riders          178
# Kings XI Punjab                176
# Chennai Super Kings            164
# Delhi Daredevils               161
# Rajasthan Royals               147
# Sunrisers Hyderabad            108
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Delhi Capitals                  16
# Rising Pune Supergiants         14
# Kochi Tuskers Kerala            14
# dtype: int64

# %%
ipl.groupby('team1').get_group('Mumbai Indians').shape[0]+ipl.groupby('team2').get_group('Mumbai Indians').shape[0]
# Out:
# 187

# %% [markdown]
# # Show the % of toss_decision

# %%
ipl.toss_decision.value_counts().plot(kind= 'pie', autopct = '%.2f%%')
plt.show()

# %% [markdown]
# # How many matches MI won till now?

# %%
print(len(ipl[ipl.winner == 'Mumbai Indians']), 'no of Matches won by MI till now')
# Out:
# 109 no of Matches won by MI till now

# %% [markdown]
# # How many matche played between MI and CSK

# %%
m = ipl[['team1','team2']]
m
# Out:
#                            team1                        team2
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 751        Kolkata Knight Riders               Mumbai Indians
# 752          Chennai Super Kings               Mumbai Indians
# 753          Sunrisers Hyderabad               Delhi Capitals
# 754               Delhi Capitals          Chennai Super Kings
# 755               Mumbai Indians          Chennai Super Kings
#
# [756 rows x 2 columns]

# %%
len(m.query('team2=="Mumbai Indians"').query('team1=="Chennai Super Kings"'))
# Out:
# 12

# %%
len(m.query('team2=="Chennai Super Kings"').query('team1=="Mumbai Indians"'))
# Out:
# 16

# %%
len(m.query('team2=="Mumbai Indians"').query('team1=="Chennai Super Kings"')) + len(m.query('team2=="Chennai Super Kings"').query('team1=="Mumbai Indians"'))
# Out:
# 28

# %% [markdown]
# # Find out top 10 player_of_match from season 2013

# %%
ipl.groupby('Season').get_group('IPL-2013').player_of_match.value_counts().head(10)
# Out:
# MEK Hussey     5
# A Mishra       4
# AM Rahane      3
# KA Pollard     3
# CH Gayle       3
# MS Dhoni       3
# V Kohli        3
# DA Miller      3
# JH Kallis      2
# JP Faulkner    2
# Name: player_of_match, dtype: int64

# %% [markdown]
# # How many times by Sachine Tendulkar received player_of _match award

# %%
print(len(ipl[ipl.player_of_match=='SR Tendulkar']),'no of times Sachin Tendulkar received player_of _match award')
# Out:
# 8 no of times Sachin Tendulkar received player_of _match award

# %% [markdown]
# # Find out the count of total no of matches played in Mumbai and Delhi

# %%
ipl[ipl['city']=='Mumbai'].append(ipl[ipl['city']=='Delhi'])
# Out:
#         id    Season    city        date                   team1  \
# 6        7  IPL-2017  Mumbai  09-04-2017   Kolkata Knight Riders
# 9       10  IPL-2017  Mumbai  12-04-2017     Sunrisers Hyderabad
# 15      16  IPL-2017  Mumbai  16-04-2017           Gujarat Lions
# 23      24  IPL-2017  Mumbai  22-04-2017          Mumbai Indians
# 27      28  IPL-2017  Mumbai  24-04-2017  Rising Pune Supergiant
# ..     ...       ...     ...         ...                     ...
# 711  11152  IPL-2019   Delhi  04-04-2019          Delhi Capitals
# 729  11325  IPL-2019   Delhi  18-04-2019          Mumbai Indians
# 732  11328  IPL-2019   Delhi  20-04-2019         Kings XI Punjab
# 741  11337  IPL-2019   Delhi  28-04-2019          Delhi Capitals
# 748  11344  IPL-2019   Delhi  04-05-2019        Rajasthan Royals
#
#                            team2          toss_winner toss_decision  result  \
# 6                 Mumbai Indians       Mumbai Indians         field  normal
# ...

# %% [markdown]
# # If my place is Pune and Team is Delhi Daredevils then how many times they won?

# %%
print((ipl[ipl.city=='Pune'].winner=='Delhi Daredevils').sum(), 'no of times Delhi Daredevils won')
# Out:
# 3 no of times Delhi Daredevils won

# %% [markdown]
# # What is the percentage of toss win for KKR

# %%
print(len(ipl[ipl.toss_winner=='Kolkata Knight Riders'])*100/len(ipl),'%')
# Out:
# 12.16931216931217 %

# %%
(ipl.toss_winner=='Rising Pune Supergiant').sum()
# Out:
# 6

# %%
ipl.toss_winner.value_counts().plot(kind = 'bar')

# %%
ipl.toss_winner.value_counts().plot(kind = 'box')
plt.show()

# %%
#Winning percentages of teams
ipl.winner.value_counts().head().plot(kind = 'pie', autopct= '%.1f%%',explode = [0.1,0.05,0,0,0])
plt.show()

# %%
ipl[ipl.win_by_runs==ipl.win_by_runs.max()]
# Out:
#     id    Season   city        date           team1             team2  \
# 43  44  IPL-2017  Delhi  06-05-2017  Mumbai Indians  Delhi Daredevils
#
#          toss_winner toss_decision  result  dl_applied          winner  \
# 43  Delhi Daredevils         field  normal           0  Mumbai Indians
#
#     win_by_runs  win_by_wickets player_of_match             venue  \
# 43          146               0     LMP Simmons  Feroz Shah Kotla
#
#         umpire1    umpire2 umpire3
# 43  Nitin Menon  CK Nandan     NaN

# %% [markdown]
# Here Mumabi Indians won by highest run 146 against Delhi Daredevils

# %%
#How many matches does MI played at Mumbai
ipl.groupby('city').get_group('Mumbai').query('team1=="Mumbai Indians" or team2== "Mumbai Indians"').shape[0]
# Out:
# 82

# %%
#How many matches does MI played and won the matches at Mumbai
ipl.groupby('city').get_group('Mumbai').query('winner=="Mumbai Indians"').shape[0]
# Out:
# 53

# %%
x = [53, 82-53]

# %%
plt.pie(x, autopct = "%.2f%%", labels = ['winning','lossing'])
plt.show()

# %%
# How many time does toss winner team won the match based on bat or field decision
df =pd.DataFrame()
ipl.groupby('Season').get_group('IPL-2017').query('toss_winner==winner').toss_decision.value_counts().plot(kind= 'bar',color = 'c')
plt.title('Winning rate vs bat or filed decision', c = 'r')
plt.show()
#ipl.groupby('Season').get_group('IPL-2018').query('toss_winner==winner').toss_decision.value_counts().plot(kind= 'bar',color = 'k')

# %%
for i in ipl.groupby('Season'):
    #print(i[1].query('toss_winner==winner').toss_decision.value_counts())
    df = df.append(i[1].query('toss_winner==winner').toss_decision.value_counts(), ignore_index=True)

# %%
df
# Out:
#      bat  field
# 0    9.0   19.0
# 1   19.0   14.0
# 2   21.0   10.0
# 3   11.0   27.0
# 4   15.0   18.0
# 5   21.0   15.0
# 6    6.0   24.0
# 7   14.0   14.0
# 8    2.0   32.0
# 9    6.0   28.0
# 10   5.0   27.0
# 11   5.0   31.0

# %%
ind = []
for i in list(ipl.groupby('Season')):
    ind.append(i[0])
print(ind)
# Out:
# ['IPL-2008', 'IPL-2009', 'IPL-2010', 'IPL-2011', 'IPL-2012', 'IPL-2013', 'IPL-2014', 'IPL-2015', 'IPL-2016', 'IPL-2017', 'IPL-2018', 'IPL-2019']

# %%
df.rename(index = pd.Series(ind))
# Out:
#            bat  field
# IPL-2008   9.0   19.0
# IPL-2009  19.0   14.0
# IPL-2010  21.0   10.0
# IPL-2011  11.0   27.0
# IPL-2012  15.0   18.0
# IPL-2013  21.0   15.0
# IPL-2014   6.0   24.0
# IPL-2015  14.0   14.0
# IPL-2016   2.0   32.0
# IPL-2017   6.0   28.0
# IPL-2018   5.0   27.0
# IPL-2019   5.0   31.0

# %%
df[['bat','field']].plot(kind='bar')
plt.xticks(range(12),ind)
plt.show()

# %%
plt.boxplot(df[['bat','field']])
plt.show()

# %%
sns.distplot(df['bat'], color = 'r')

# %%
ipl
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
ipl[ipl.winner == 'Sunrisers Hyderabad'].query('win_by_runs>35')
# Out:
#         id    Season           city        date                team1  \
# 35      36  IPL-2017      Hyderabad  30-04-2017  Sunrisers Hyderabad
# 612    613  IPL-2016  Visakhapatnam  08-05-2016  Sunrisers Hyderabad
# 706  11147  IPL-2019      Hyderabad  31-03-2019  Sunrisers Hyderabad
# 743  11339  IPL-2019      Hyderabad  29-04-2019  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 35         Kolkata Knight Riders        Kolkata Knight Riders         field
# 612               Mumbai Indians               Mumbai Indians         field
# 706  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 743              Kings XI Punjab              Kings XI Punjab         field
#
#      result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 35   normal           0  Sunrisers Hyderabad           48               0
# 612  normal           0  Sunrisers Hyderabad           85               0
# ...

# %%
ipl[ipl.winner == 'Sunrisers Hyderabad'].query('win_by_runs>35').shape[0]
# Out:
# 4

# %%
ipl.dl_applied.value_counts().plot.pie(autopct= '%.2f%%')

# %%
x = ipl.Season.unique()
x
# Out:
# array(['IPL-2017', 'IPL-2008', 'IPL-2009', 'IPL-2010', 'IPL-2011',
#        'IPL-2012', 'IPL-2013', 'IPL-2014', 'IPL-2015', 'IPL-2016',
#        'IPL-2018', 'IPL-2019'], dtype=object)
